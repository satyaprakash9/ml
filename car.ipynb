# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_data = pd.read_csv('/content/drive/MyDrive/ml/datasets/CarPrice_Assignment.csv')
car_data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car_data.shape
# Out:
# (205, 26)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
car_data.select_dtypes([float,int]).columns
# Out:
# Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
sns.boxplot(data=car_data,y='enginesize',x='enginetype')

# %%
sns.scatterplot(data=car_data,x='horsepower',y='price',hue='fueltype')

# %%
car_data.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# ...

# %%
car_data.duplicated().sum()
# Out:
# 0

# %%
car_data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car_data = car_data.drop('car_ID',axis=1)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(car_data.corr(),cmap='RdYlGn',annot=True)

# %%
car_corr = car_data.corr()['price']
top_features = car_corr[abs(car_corr)>0.5].index.tolist()

# %%
top_features
# Out:
# ['wheelbase',
#  'carlength',
#  'carwidth',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'horsepower',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
for col in car_data.select_dtypes([float,int]).columns:
  if col not in top_features:
    car_data = car_data.drop(col,axis=1)
car_data.head()
# Out:
#                     CarName fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  curbweight  \
# 0        rwd          front       88.6      168.8      64.1        2548
# 1        rwd          front       88.6      168.8      64.1        2548
# 2        rwd          front       94.5      171.2      65.5        2823
# 3        fwd          front       99.8      176.6      66.2        2337
# 4        4wd          front       99.4      176.6      66.4        2824
#
#   enginetype cylindernumber  enginesize fuelsystem  boreratio  horsepower  \
# ...

# %%
car_data.select_dtypes([float,int]).columns
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginesize',
#        'boreratio', 'horsepower', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
for col in car_data.select_dtypes([float,int]).columns:  
  desc = car_data[col].describe()
  iqr = desc['75%']-desc['25%']
  max = iqr*1.5 + desc['75%']
  car_data = car_data.drop(index=car_data[col][car_data[col]>max].index)

# %%
from sklearn.preprocessing import StandardScaler
s = StandardScaler()
for col in car_data.select_dtypes([float,int]).columns:
  if col != 'price':
    car_data[col] = s.fit_transform(car_data[[col]])

# %%
car_data = pd.get_dummies(car_data,columns=car_data.select_dtypes(object).columns,drop_first=True)

# %%
from scipy.stats import boxcox,normaltest
price_bc = boxcox(car_data['price'])

# %%
price_log = np.log1p(car_data['price'])

# %%
normaltest(price_bc[0])
# Out:
# NormaltestResult(statistic=31.42527232753373, pvalue=1.4999915686486313e-07)

# %%
normaltest(price_log)
# Out:
# NormaltestResult(statistic=31.893255183308707, pvalue=1.1870462270440494e-07)

# %%
car_data.price = price_log

# %%
X = car_data.drop('price',axis=1)
y = car_data['price']

# %%
car_data.price.skew()
# Out:
# 0.2535640649897922

# %%
sns.histplot(data=car_data,x='price')

# %%
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, ElasticNetCV, Lasso
from sklearn.model_selection import cross_val_predict, KFold, train_test_split, GridSearchCV
from sklearn.metrics import r2_score
pf = PolynomialFeatures(degree=2)
s = StandardScaler()
lr = LinearRegression()
kf = KFold(shuffle=True,random_state=8457,n_splits=3)
estimator = Pipeline([('polynomial_features',pf),('linear_regression',lr)])
predictions = cross_val_predict(estimator,X,y,cv=kf)

# %%
pred = cross_val_predict(lr,X,y,cv=kf)

# %%
plt.plot(np.exp(y)-1,np.exp(y)-1)

# %%
sns.scatterplot(np.exp(y)-1,np.exp(pred)-1)
plt.plot(np.exp(y)-1,np.exp(y)-1)
plt.ylim((np.exp(y)-1).min(),(np.exp(y)-1).max())
plt.xlim((np.exp(y)-1).min(),(np.exp(y)-1).max())
plt.xlabel('expected values')
plt.ylabel('predicted values')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'predicted values')

# %%
r2_score(y,pred)
# Out:
# -25.510133294378964

# %%
r2_score(y,predictions)
# Out:
# 0.5866221810803554

# %%
plt.scatter(np.exp(y)-1,np.exp(predictions)-1)
plt.plot(np.exp(y)-1,np.exp(y)-1)
plt.xlim((np.exp(y)-1).min(),(np.exp(y)-1).max())
plt.ylim((np.exp(y)-1).min(),(np.exp(y)-1).max())
plt.xlabel('expected values')
plt.ylabel('predicted values')
# Out:
# Text(0, 0.5, 'predicted values')

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.3,random_state=8457)
alphas = [1e-5, 5e-5, 0.0001, 0.0005]
lascv = LassoCV(alphas=alphas,max_iter=100000,cv=kf).fit(X_train,y_train)
r2_score(y_test,lascv.predict(X_test))
# Out:
# 0.8314247742546491

# %%
(lascv.coef_==0).sum()
# Out:
# 83

# %%
lascv.alpha_
# Out:
# 0.0005

# %%
sns.scatterplot(np.exp(y)-1,np.exp(lascv.predict(X))-1,label='predict',color='r')
sns.lineplot(np.exp(y)-1,np.exp(y)-1,label='real')
plt.ylim((np.exp(y)-1).min(),(np.exp(y)-1).max())
plt.xlim((np.exp(y)-1).min(),(np.exp(y)-1).max())
plt.xlabel('expected values')
plt.ylabel('predicted values')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'predicted values')

# %%
ridcv = RidgeCV(alphas=[0.005, 0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 80],cv=kf).fit(X_train,y_train)
r2_score(y_test,ridcv.predict(X_test))
# Out:
# 0.80243576907043

# %%
ridcv.alpha_
# Out:
# 10.0

# %%
plt.scatter(np.exp(y)-1,np.exp(ridcv.predict(X)))
plt.xlabel('expected values')
plt.ylabel('predicted values')
# Out:
# Text(0, 0.5, 'predicted values')

# %%
estimator1 = Pipeline([('poly_features',PolynomialFeatures()),('lasso',Lasso())])
params = {'poly_features__degree':[1,2,3],'lasso__alpha':[1e-5, 5e-5, 0.0001, 0.0005]}
grid = GridSearchCV(estimator1,params,cv=kf).fit(X_train,y_train)
r2_score(y_test,grid.predict(X_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.701e-02, tolerance: 9.655e-04
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.973e-02, tolerance: 1.352e-03
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.799e-02, tolerance: 1.178e-03
#
# ...

# %%
elastic_cv = ElasticNetCV(alphas=alphas,l1_ratio=np.linspace(0,1,10),max_iter=100000).fit(X_train,y_train)
r2_score(y_test,elastic_cv.predict(X_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.231e-01, tolerance: 1.376e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.951e-02, tolerance: 1.376e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#
# ...
